# %%
import tensorflow as tf
import matplotlib as plt

# %%
data=tf.keras.datasets.mnist
(x_train,y_train),(x_test,y_test)=data.load_data()

# %%
print("train data",x_train.shape)
print("train labels",y_train.shape)
print("test data",x_test.shape)
print("train labels",y_test.shape)

x_train=tf.keras.utils.normalize(x_train,axis=1)
# Out:
# train data (60000, 28, 28)
# train labels (60000,)
# test data (10000, 28, 28)
# train labels (10000,)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(64,activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))

model.compile(optimizer="adam",loss='sparse_categorical_crossentropy',metrics=['accuracy'])

model.fit(x_train,y_train,epochs=1)

#earlystop=tf.keras.callbacks.EarlyStopping(monitor='loss',patience=10)
#model.fit(x_train,y_train,epochs=50,validation_split=0.2,verbose=1,callbacks=[earlystop])

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model.compile(optimizer="adam",loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,epochs=1)
# Out:
# Epoch 1/1
# ...
#  7840/60000 [==>...........................] - ETA: 11:42 - loss: 3.5091 - acc: 0.4272WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.110732). Check your callbacks.
# ...
# ...
# 59968/60000 [============================>.] - ETA: 0s - loss: 3.9343 - acc: 0.2972WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.345462). Check your callbacks.
# WARNING:tensorflow:Method on_batch_end() is slow compared to the batch update (0.336758). Check your callbacks.
# 60000/60000 [==============================] - 996s 17ms/step - loss: 3.9340 - acc: 0.2972

# %%
loss,accuracy=model.evaluate(x_test,y_test)
print(loss,"\naccuracy=",accuracy)
# Out:
# 10000/10000 [==============================] - 1s 105us/step
# 0.40992150546288975
# accuracy= 0.9745

# %%
#Numebr of epochs=1
    #adam 2 layers (train,test)
        #1024  94.22 , 96.42
        #512   93.91,95.33
        #256   93.31 ,95.39
